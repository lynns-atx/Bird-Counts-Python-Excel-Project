# %% [markdown]
# # Table of Contents
# ## 1. Import Libraries & Data
# ## 2. Exploring Data
# ## 3. Data Cleaning
# ## 4. Data Wrangling
# ## 5. Creating a Table with Only Birds
# ## 6. Save Data

# %% [markdown]
# ## 1. Import Libraries & Data

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
#Import Data
lp = pd.read_csv(r'/Users/lynnsey/Desktop/Bootcamp/Tasks/Immersion/Task 6/09-07-2023 Living Planet Index Analysis/02 Data/Original Data/LPD2022_public.csv', index_col = False)
# Out:
# /var/folders/kk/6z0tdmb13cd8dwpkbrq630qw0000gn/T/ipykernel_26725/59007774.py:2: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   lp = pd.read_csv(r'/Users/lynnsey/Desktop/Bootcamp/Tasks/Immersion/Task 6/09-07-2023 Living Planet Index Analysis/02 Data/Original Data/LPD2022_public.csv', index_col = False)

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 2. Exploring Data

# %%
# Looking at first 5 rows of data
lp.head()
# Out:
#    ID                   Binomial  Replicate  \
# 0   1        Balearica_regulorum          1
# 1   2  Acrocephalus_sechellensis          1
# 2   3      Copsychus_sechellarum          1
# 3   4      Copsychus_sechellarum          0
# 4   5            Falco_punctatus          0
#
#                                             Citation Class          Order  \
# 0  Pomeroy, D. and P. Mwima (2002). The State of ...  Aves     Gruiformes
# 1  Rands, M. (1989). "Saving the Seychelles brush...  Aves  Passeriformes
# 2  Komdeur, J. (1996). "Breeding of the Seychelle...  Aves  Passeriformes
# 3  Komdeur, J. (1996). "Breeding of the Seychelle...  Aves  Passeriformes
# 4  Groombridge, J. J., Bruford, M.W., Jones, C.G,...  Aves  Falconiformes
#
#            Family         Genus       Species Subspecies         Authority  \
# 0         Gruidae     Balearica     regulorum        NaN   (Bennett, 1834)
# 1  Acrocephalidae  Acrocephalus  sechellensis        NaN  (Oustalet, 1877)
# ...

# %%
# Doing descriptive statistics
lp.describe()
# Out:
#                   ID     Replicate      Latitude     Longitude  \
# count   32680.000000  32680.000000  32672.000000  32672.000000
# mean    50782.992105      0.177020     11.812923     16.052034
# std     59913.726284      0.381691     36.692082     99.548572
# min         1.000000      0.000000    -78.193822   -180.000000
# 25%      8907.750000      0.000000    -24.229471    -65.298586
# 50%     20213.500000      0.000000     13.544170      5.955000
# 75%    102543.250000      0.000000     46.754910    137.243782
# max    500007.000000      1.000000     81.000000    180.000000
#
#        Specific_location  Migratory_fw_fish          1950          1951  \
# count       32672.000000       32680.000000  2.580000e+02  2.400000e+02
# mean            0.398843           0.041983  9.887141e+12  1.046159e+13
# std             0.489668           0.200553  1.556606e+14  1.588098e+14
# min             0.000000           0.000000  0.000000e+00  0.000000e+00
# ...

# %% [markdown]
# ## 3. Data Cleaning

# %%
# Getting counts for each variable
lp.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32680 entries, 0 to 32679
# Data columns (total 103 columns):
#  #    Column             Non-Null Count  Dtype
# ---   ------             --------------  -----
#  0    ID                 32680 non-null  int64
#  1    Binomial           32680 non-null  object
#  2    Replicate          32680 non-null  int64
#  3    Citation           32680 non-null  object
#  4    Class              32680 non-null  object
#  5    Order              32680 non-null  object
#  6    Family             32680 non-null  object
#  7    Genus              32680 non-null  object
#  8    Species            32680 non-null  object
#  9    Subspecies         1229 non-null   object
#  10   Authority          21970 non-null  object
#  11   Common_name        32680 non-null  object
#  12   Location           32680 non-null  object
#  13   Country            32680 non-null  object
#  14   All_countries      32656 non-null  object
# ...

# %%
# Create a subset with only duplicates
lp_dups=lp[lp.duplicated()]

# %%
# Looking at duplicates
lp_dups.head()
# Out:
# Empty DataFrame
# Columns: [ID, Binomial, Replicate, Citation, Class, Order, Family, Genus, Species, Subspecies, Authority, Common_name, Location, Country, All_countries, Region, IPBES_region, IPBES_subregion, Latitude, Longitude, Specific_location, System, T_realm, T_biome, FW_realm, FW_biome, M_realm, M_ocean, M_biome, Migratory_fw_fish, Units, Method, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, ...]
# Index: []

# %% [markdown]
# ### No duplicates to remove

# %%
# Looking at last 5 rows of data
lp.tail()
# Out:
#            ID              Binomial  Replicate  \
# 32675  500003      Platanista_minor          0
# 32676  500004      Platanista_minor          0
# 32677  500005      Platanista_minor          0
# 32678  500006      Platanista_minor          0
# 32679  500007  Platanista_gangetica          0
#
#                                                 Citation     Class    Order  \
# 32675        WWF (2018) River Dolphin Strategy 2018-2030  Mammalia  Cetacea
# 32676  Chaudhry, A.A., Maan, A.M., Akbar, M., 1999. C...  Mammalia  Cetacea
# 32677  Chaudhry, A.A., Maan, A.M., Akbar, M., 1999. C...  Mammalia  Cetacea
# 32678  Braulik, G. T., Z. I. Bhatti, T. Ehsan, B. Hus...  Mammalia  Cetacea
# 32679        WWF (2018) River Dolphin Strategy 2018-2030  Mammalia  Cetacea
#
#               Family       Genus    Species Subspecies   Authority  \
# 32675  Platanistidae  Platanista      minor        NaN  Owen, 1853
# 32676  Platanistidae  Platanista      minor        NaN  Owen, 1853
# ...

# %% [markdown]
# ## 4. Data Wrangling

# %% [markdown]
# ### Dropping columns not needed for analysis

# %%
lp_v2 = lp.drop(columns = ['Replicate', 'Citation', 'Order', 'Family', 'Genus', 'Species', 'Subspecies', 'Authority', 'Location', 'All_countries', 'IPBES_region', 'IPBES_subregion', 'Method'])

# %%
lp_v2.head()
# Out:
#    ID                   Binomial Class              Common_name     Country  \
# 0   1        Balearica_regulorum  Aves       Grey-crowned crane      Uganda
# 1   2  Acrocephalus_sechellensis  Aves       Seychelles warbler  Seychelles
# 2   3      Copsychus_sechellarum  Aves  Seychelles magpie-robin  Seychelles
# 3   4      Copsychus_sechellarum  Aves  Seychelles magpie-robin  Seychelles
# 4   5            Falco_punctatus  Aves        Mauritius kestrel   Mauritius
#
#    Region  Latitude  Longitude  Specific_location       System       T_realm  \
# 0  Africa  -0.07889   31.13306                0.0  Terrestrial  Afrotropical
# 1  Africa  -4.33333   55.66667                1.0  Terrestrial  Afrotropical
# 2  Africa  -4.58333   55.66667                0.0  Terrestrial  Afrotropical
# 3  Africa  -4.58333   55.93333                1.0  Terrestrial  Afrotropical
# 4  Africa -20.30000   57.58333                0.0  Terrestrial  Afrotropical
#
# ...

# %% [markdown]
# ### Renaming columns to better interpret

# %%
# Renaming Binomial to scientific_name
lp_v2.rename(columns = {'Binomial' : 'scientific_name'}, inplace = True)

# %%
# Renaming ID to id
lp_v2.rename(columns = {'ID' : 'id'}, inplace = True)

# %%
# Renaming Common_name to common_name
lp_v2.rename(columns = {'Common_name' : 'common_name'}, inplace = True)

# %%
# Renaming Country to country
lp_v2.rename(columns = {'Country' : 'country'}, inplace = True)

# %%
# Renaming Region to region
lp_v2.rename(columns = {'Region' : 'region'}, inplace = True)

# %%
# Renaming Latitude to latitude
lp_v2.rename(columns = {'Latitude' : 'latitude'}, inplace = True)

# %%
# Renaming Specific_location to specific_location
lp_v2.rename(columns = {'Specific_location' : 'specific_location'}, inplace = True)

# %%
# Renaming System to system
lp_v2.rename(columns = {'System' : 'system'}, inplace = True)

# %%
# Renaming T_realm to terrestrial_realm
lp_v2.rename(columns = {'T_realm' : 'terrestrial_realm'}, inplace = True)

# %%
# Renaming T_biome to terrestrial_biome
lp_v2.rename(columns = {'T_biome' : 'terrestrial_biome'}, inplace = True)

# %%
# Renaming FW_realm to freshwater_realm
lp_v2.rename(columns = {'FW_realm' : 'freshwater_realm'}, inplace = True)

# %%
# Renaming M_realm to marine_realm
lp_v2.rename(columns = {'M_realm' : 'marine_realm'}, inplace = True)

# %%
# Renaming M_biome to marine_biome
lp_v2.rename(columns = {'M_biome' : 'marine_biome'}, inplace = True)

# %%
# Renaming Migratory_fw_fish to migratory_freshwater_fish
lp_v2.rename(columns = {'Migratory_fw_fish' : 'migratory_freshwater_fish'}, inplace = True)

# %%
# Renaming Units to units_used_for_count
lp_v2.rename(columns = {'Units' : 'units_used_for_count'}, inplace = True)

# %%
# Renaming Class to class
lp_v2.rename(columns = {'Class' : 'class'}, inplace = True)

# %%
# Renaming M_ocean to marine_ocean
lp_v2.rename(columns = {'M_ocean' : 'marine_ocean'}, inplace = True)

# %%
# Renaming Longitude to longitude
lp_v2.rename(columns = {'Longitude' : 'longitude'}, inplace = True)

# %%
# Renaming FW_biome to freshwater_biome
lp_v2.rename(columns = {'FW_biome' : 'freshwater_biome'}, inplace = True)

# %%
# Checking if columns renamed properly
lp_v2.head()
# Out:
#    id            scientific_name class              common_name     country  \
# 0   1        Balearica_regulorum  Aves       Grey-crowned crane      Uganda
# 1   2  Acrocephalus_sechellensis  Aves       Seychelles warbler  Seychelles
# 2   3      Copsychus_sechellarum  Aves  Seychelles magpie-robin  Seychelles
# 3   4      Copsychus_sechellarum  Aves  Seychelles magpie-robin  Seychelles
# 4   5            Falco_punctatus  Aves        Mauritius kestrel   Mauritius
#
#    region  latitude  longitude  specific_location       system  \
# 0  Africa  -0.07889   31.13306                0.0  Terrestrial
# 1  Africa  -4.33333   55.66667                1.0  Terrestrial
# 2  Africa  -4.58333   55.66667                0.0  Terrestrial
# 3  Africa  -4.58333   55.93333                1.0  Terrestrial
# 4  Africa -20.30000   57.58333                0.0  Terrestrial
#
#   terrestrial_realm                                  terrestrial_biome  \
# ...

# %%
# Checking data types
lp_v2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32680 entries, 0 to 32679
# Data columns (total 90 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         32680 non-null  int64
#  1   scientific_name            32680 non-null  object
#  2   class                      32680 non-null  object
#  3   common_name                32680 non-null  object
#  4   country                    32680 non-null  object
#  5   region                     32680 non-null  object
#  6   latitude                   32672 non-null  float64
#  7   longitude                  32672 non-null  float64
#  8   specific_location          32672 non-null  float64
#  9   system                     32680 non-null  object
#  10  terrestrial_realm          9925 non-null   object
#  11  terrestrial_biome          9562 non-null   object
#  12  freshwater_realm           7702 non-null   object
# ...

# %%
# Checking for mixed data types
for col in lp_v2.columns:
    weird = (lp_v2[[col]].applymap(type) != lp_v2[[col]].iloc[0].apply(type)).any(axis=1)
    if len(lp_v2[weird]) > 0:
        print(col)
# Out:
# terrestrial_realm
# terrestrial_biome
# freshwater_realm
# freshwater_biome
# marine_realm
# marine_ocean
# marine_biome
# units_used_for_count

# %% [markdown]
# ### Fixing all mixed data types

# %%
lp_v2['terrestrial_realm'] = lp_v2['terrestrial_realm'].astype('str')

# %%
lp_v2['terrestrial_biome'] = lp_v2['terrestrial_biome'].astype('str')

# %%
lp_v2['freshwater_realm'] = lp_v2['freshwater_realm'].astype('str')

# %%
lp_v2['freshwater_biome'] = lp_v2['freshwater_biome'].astype('str')

# %%
lp_v2['marine_realm'] = lp_v2['marine_realm'].astype('str')

# %%
lp_v2['marine_ocean'] = lp_v2['marine_ocean'].astype('str')

# %%
lp_v2['marine_biome'] = lp_v2['marine_biome'].astype('str')

# %%
lp_v2['units_used_for_count'] = lp_v2['units_used_for_count'].astype('str')

# %%
# Checking to make sure caught all mixed types
for col in lp_v2.columns:
    weird = (lp_v2[[col]].applymap(type) != lp_v2[[col]].iloc[0].apply(type)).any(axis=1)
    if len(lp_v2[weird]) > 0:
        print(col)

# %% [markdown]
# ### Changing data types to appropriate ones

# %%
lp_v2['id'] = lp_v2 ['id'].astype('str')

# %%
lp_v2['specific_location'] = lp_v2 ['specific_location'].astype('bool')

# %%
lp_v2['migratory_freshwater_fish'] = lp_v2 ['migratory_freshwater_fish'].astype('bool')

# %%
# Checking data types again
lp_v2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32680 entries, 0 to 32679
# Data columns (total 90 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         32680 non-null  object
#  1   scientific_name            32680 non-null  object
#  2   class                      32680 non-null  object
#  3   common_name                32680 non-null  object
#  4   country                    32680 non-null  object
#  5   region                     32680 non-null  object
#  6   latitude                   32672 non-null  float64
#  7   longitude                  32672 non-null  float64
#  8   specific_location          32680 non-null  bool
#  9   system                     32680 non-null  object
#  10  terrestrial_realm          32680 non-null  object
#  11  terrestrial_biome          32680 non-null  object
#  12  freshwater_realm           32680 non-null  object
# ...

# %% [markdown]
# ## 5. Creating a Table with Only Birds

# %%
#Creating a table with only data on birds
birds = lp_v2.loc[(lp_v2['class'] == 'Aves')]

# %%
#Checking if done correctly
birds.head()
# Out:
#   id            scientific_name class              common_name     country  \
# 0  1        Balearica_regulorum  Aves       Grey-crowned crane      Uganda
# 1  2  Acrocephalus_sechellensis  Aves       Seychelles warbler  Seychelles
# 2  3      Copsychus_sechellarum  Aves  Seychelles magpie-robin  Seychelles
# 3  4      Copsychus_sechellarum  Aves  Seychelles magpie-robin  Seychelles
# 4  5            Falco_punctatus  Aves        Mauritius kestrel   Mauritius
#
#    region  latitude  longitude  specific_location       system  \
# 0  Africa  -0.07889   31.13306              False  Terrestrial
# 1  Africa  -4.33333   55.66667               True  Terrestrial
# 2  Africa  -4.58333   55.66667              False  Terrestrial
# 3  Africa  -4.58333   55.93333               True  Terrestrial
# 4  Africa -20.30000   57.58333              False  Terrestrial
#
#   terrestrial_realm                                  terrestrial_biome  \
# ...

# %%
#Checking if done correctly
birds.tail()
# Out:
#            id          scientific_name class             common_name country  \
# 30699  200634  Nannopterum_brasilianus  Aves   Neotropical cormorant  Brazil
# 30700  200635  Nannopterum_brasilianus  Aves   Neotropical cormorant  Brazil
# 30701  200636  Nannopterum_brasilianus  Aves   Neotropical cormorant  Brazil
# 30703  200638          Tyrannus_savana  Aves  Fork-tailed flycatcher  Brazil
# 30704  200639         Sula_leucogaster  Aves             Brown booby  Brazil
#
#                             region   latitude  longitude  specific_location  \
# 30699  Latin America and Caribbean -22.675712 -43.086199              False
# 30700  Latin America and Caribbean -22.694635 -43.063937              False
# 30701  Latin America and Caribbean -22.694635 -43.063937              False
# 30703  Latin America and Caribbean -15.550000 -47.700000              False
# 30704  Latin America and Caribbean -27.850000 -48.433333               True
#
# ...

# %% [markdown]
# ## 7. Look at units_used_for_count more closely

# %%
# See all unique values for units_used_for_count
birds['units_used_for_count'].unique()
# Out:
# array(['Mean number of counts per route', 'Individuals',
#        'Total population number', 'Number of individuals',
#        'Number of breeding pairs', 'Mean number of individuals',
#        'Number of nests', 'Breeding pairs',
#        'Breeding pairs - sub-population', 'Population estimate',
#        'Active nests', 'Number of nesting pairs',
#        'Number of indidviduals', 'Number of pre-breeding individuals',
#        'Index', 'Number of skylarks per 100000 birds ringed',
#        'Population index', 'Total spring population count',
#        'Number of tree pipits per 100000 birds ringed', 'pairs',
#        'Yearly maximum number of individuals', 'Index of abundance',
#        'index based on bird-days', 'Unknown', 'Annual population index',
#        'Number of breeding birds', 'Log number of nestlings',
#        'Density (pairs/100km squares)', 'Number of pairs',
#        'Number of territories per km2', 'Number of calling males',
# ...

# %% [markdown]
# ## 6. Save Data

# %%
#Exporting the data
birds.to_csv(r'/Users/lynnsey/Desktop/Bootcamp/Tasks/Immersion/Task 6/09-07-2023 Living Planet Index Analysis/02 Data/Prepared Data/birds_v1.csv')

# %% [markdown]
# ### There is a lot of variation in the units used to collect the data.  I examined more closely in Excel and decided to use individuals as the unit to compare.  I deleted all records that used density or an unknown method.  If the birds were counted in pairs, I double the counts.  If they were counted in thousands or pairs, I multiplied the number by 2,000 for each year.  If the unit was a percentage, I removed those records.  In total, 7% of the data was removed after cleaning up the units.
