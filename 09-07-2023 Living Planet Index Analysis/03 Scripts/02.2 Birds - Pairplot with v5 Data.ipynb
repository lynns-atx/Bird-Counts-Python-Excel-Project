# %% [markdown]
# # Table of Contents
# ## 1. Import Libraries & Data
# ## 2. Create a Pair Plot
# ## 3. Save Data

# %% [markdown]
# #### Note: Between this notebook and the last one, I removed all records missing all population counts in excel; removed 1,794 records.  Left with 12,920

# %% [markdown]
# ## 1. Import Libraries & Data

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
#Import Data
birds = pd.read_csv(r'/Users/lynnsey/Desktop/Bootcamp/Tasks/Immersion/Task 6/09-07-2023 Living Planet Index Analysis/02 Data/Prepared Data/birds_v5.csv', index_col = False)

# %%
#Show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 5. Create a Pair Plot

# %%
#Create a dataframe with only relevant columns
birds_pair = birds.drop(columns = ['id', 'class', 'family', 'genus', 'species', 'common_name', '1950', '1951', '1952', '1953', '1954', '1955', '1956', '1957', '1958', '1959', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'])

# %%
birds_pair.head()
# Out:
#              scientific_name          order     country  region       system  \
# 0        Balearica_regulorum     Gruiformes      Uganda  Africa  Terrestrial
# 1  Acrocephalus_sechellensis  Passeriformes  Seychelles  Africa  Terrestrial
# 2      Copsychus_sechellarum  Passeriformes  Seychelles  Africa  Terrestrial
# 3      Copsychus_sechellarum  Passeriformes  Seychelles  Africa  Terrestrial
# 4            Falco_punctatus  Falconiformes   Mauritius  Africa  Terrestrial
#
#    avg_1950_to_1974  avg_1975_to_1999  avg_2000_to_2020
# 0              1962                 7                11
# 1                30               352                 0
# 2                30                27                 0
# 3                 0                29                 0
# 4                 2                31                 0

# %%
# Create a pair plot 
pair = sns.pairplot(birds_pair, diag_kws = {"bins": 10})

# %%
# Create a pair plot 
pair = sns.pairplot(birds_pair)
